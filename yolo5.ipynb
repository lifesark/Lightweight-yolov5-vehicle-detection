# %%
# Mount Google Drive to store files
from google.colab import drive
drive.mount('/content/drive')

# Update and install dependencies
# !pip install torch torchvision numpy opencv-python matplotlib tqdm
# !pip install ultralytics

# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
# ...

# %%
# !cp -r /content/drive/MyDrive/UA-DETRAC-small /content/

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("CUDA Device Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# CUDA Device Name: Tesla T4

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch

# Set PyTorch to use all available GPU memory
torch.cuda.empty_cache()
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True

# %%
import torch

# Allocate full GPU memory at the start
torch.cuda.set_per_process_memory_fraction(1.0, 0)
print(f"Using {torch.cuda.memory_allocated() / 1e9:.2f} GB of GPU memory")
# Out:
# Using 0.00 GB of GPU memory

# %%
# !nvidia-smi

# %%
import torch

# Set PyTorch to always use GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_per_process_memory_fraction(1.0, 0)  # Allocate full GPU
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
print(f"Using {device}, {torch.cuda.memory_allocated() / 1e9:.2f} GB of GPU memory")
# Out:
# Using cuda, 0.00 GB of GPU memory

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("CUDA Device:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# CUDA Device: Tesla T4

# %%
# !pip uninstall torch torchvision -y
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.5.1+cu124
# Uninstalling torch-2.5.1+cu124:
#   Successfully uninstalled torch-2.5.1+cu124
# Found existing installation: torchvision 0.20.1+cu124
# Uninstalling torchvision-0.20.1+cu124:
#   Successfully uninstalled torchvision-0.20.1+cu124
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.7/848.7 MB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 90.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 42.6 MB/s eta 0:00:00
# ...

# %%
import torch

torch.cuda.empty_cache()
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
torch.cuda.set_per_process_memory_fraction(1.0, 0)

print(f"GPU Memory Allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
# Out:
# GPU Memory Allocated: 0.00 GB

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !grep -A 5 "class C3x" /content/yolov5/models/common.py

# %%
# !grep -A 10 "class SCConv" /content/yolov5/models/common.py

# %%
# !grep -A 5 "class Conv" /content/yolov5/models/common.py

# %%
# !rm -rf /content/drive/MyDrive/YOLOv5_Training/weights/*.pt

# %%
# !grep -A 10 "class IPA" /content/yolov5/models/common.py
# !grep -A 10 "class MSCCR" /content/yolov5/models/common.py

# %%
# !grep "class IPA" /content/yolov5/models/common.py
# Out:
# class IPA(nn.Module):

# %%
import torch
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Thu Mar 13 19:13:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0             30W /   70W |     102MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --batch 8 --epochs 10 --data /content/UA-DETRAC-small/dataset.yaml \
--cfg /content/yolov5/models/yolov5s.yaml --weights '' --cache --device 0 --noval \
--optimizer AdamW --cos-lr --save-period 10 \
--project "/content/drive/MyDrive/YOLOv5_Training"
# Out:
# /content/yolov5
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-15 10:46:03.975566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742035564.288923   10888 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !cp /content/drive/MyDrive/YOLOv5_Training/exp/weights/epoch10.pt /content/yolov5/
# Out:
# cp: cannot stat '/content/drive/MyDrive/YOLOv5_Training/exp/weights/epoch10.pt': No such file or directory

# %%
# %cd /content/yolov5

# Clear GPU cache first (optional but recommended)
import torch; torch.cuda.empty_cache()

# !python train.py \
--img 640 \
--batch 4 \
--epochs 10 \
--data /content/UA-DETRAC-small/dataset.yaml \
--cfg /content/yolov5/models/yolov5s.yaml \
--weights '' \
--cache \
--device 0 \
--optimizer AdamW \
--cos-lr \
--save-period 10 \
--workers 2 \
--project "/content/drive/MyDrive/YOLOv5_Training"
# Out:
# /content/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-15 10:56:24.406507: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742036184.440415   13789 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742036184.450875   13789 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --batch 8 --epochs 10 --data /content/UA-DETRAC-small/dataset.yaml \
--cfg /content/yolov5/models/yolov5s.yaml --weights '' --cache --device 0 \
--optimizer AdamW --cos-lr --save-period 10 --workers 2 \
--project "/content/drive/MyDrive/YOLOv5_Training"
# Out:
# /content/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-15 10:49:14.278237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742035754.298899   11857 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742035754.305182   11857 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# ...

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data /content/UA-DETRAC-small/dataset.yaml --weights yolov5s.pt --cache --device 0 --workers 4
# Out:
# Streaming output truncated to the last 5000 lines.
#        4/49      13.7G    0.03302    0.04132   0.006297        748        640:  64% 86/135 [01:25<00:45,  1.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/49      13.7G      0.033    0.04125   0.006303        646        640:  64% 87/135 [01:26<00:43,  1.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/49      13.7G    0.03301    0.04122   0.006301        761        640:  65% 88/135 [01:27<00:42,  1.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !ls /content/drive/MyDrive/YOLOv5_Training/exp/weights/
# Out:
# ls: cannot access '/content/drive/MyDrive/YOLOv5_Training/exp/weights/': No such file or directory

# %%
# !python train.py --img 640 --batch 32 --epochs 50 --data /content/drive/MyDrive/UA-DETRAC-small/dataset.yaml --weights yolov5s.pt --cache --device 0
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/seaborn/widgets.py", line 6, in <module>
#     from ipywidgets import interact, FloatSlider, IntSlider
#   File "/usr/local/lib/python3.11/dist-packages/ipywidgets/__init__.py", line 25, in <module>
#     from .widgets import *
#   File "/usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/__init__.py", line 21, in <module>
#     from .widget_string import HTML, HTMLMath, Label, Text, Textarea, Password, Combobox
#   File "/usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_string.py", line 62, in <module>
#     class Textarea(_String):
# ...

# %%
git add
